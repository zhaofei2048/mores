# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from fresnel import *

# %%
theta_is = np.linspace(1, 70, 70)
theta_cs = np.zeros(len(theta_is))

er_r = 8
for i in range(len(theta_is)):
    theta_cs[i] = refraction_angle(theta_is[i], er_r)
    # theta_cs[i] = TransmissionAngle(theta_is[i], er_r)

plt.plot(theta_is, theta_cs)
# plt.plot(np.sin(np.deg2rad(theta_is)), np.sqrt(er_r)*np.sin(np.deg2rad(theta_cs))-np.sin(np.deg2rad(theta_is)))
plt.xlabel('incident angle (deg)')
plt.ylabel('refraction angle (deg)')
# Out:
# Text(0, 0.5, 'refraction angle (deg)')

# %%
refraction_angle(90, er_r)
# Out:
# 20.70481105463543

# %%
import numpy as np
10*np.log10(np.cos(60*3.14/180))
# Out:
# -3.006308982972445
