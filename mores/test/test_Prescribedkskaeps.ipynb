# %%
import sys
sys.path.append('..')
from Prescribedkskaeps import Prescribedkskaeps

# %%
ke = 1
a = 0.1
layer = Prescribedkskaeps(3e9, 1.0, ke*(1-a), ke*a)

# %%
layer.phase_matrix(())
# Out:
# array([[0.07161972, 0.        , 0.        , 0.        ],
#        [0.        , 0.07161972, 0.        , 0.        ],
#        [0.        , 0.        , 0.07161972, 0.        ],
#        [0.        , 0.        , 0.        , 0.07161972]])

# %%
layer.extinction_matrix()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 layer.extinction_matrix()
#
# TypeError: extinction_matrix() missing 1 required positional argument: 'direction'
