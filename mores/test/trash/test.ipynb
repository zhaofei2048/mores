# %%
import sys
sys.path.append("../..")

# %%
# %run ./test.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File E:\exps\lunar_scattering\lunar_regolith_scattering\mores\mores\test\test.py:2
# ----> 2 from mores.interface.IEM import test_func
#       4 test_func()
#
# ModuleNotFoundError: No module named 'mores'
