# %%
import sys
sys.path.append("../..")

# %%
from scipy.special import kv

# %%
kv(5, 2)
# Out:
# 9.431049100596468

# %%
from scipy.special import jn as besselj

# %%
besselj(2, 3)
# Out:
# 0.4860912605858912

# %%
import numpy as np
a = 2
np.shape(a)
# Out:
# ()
