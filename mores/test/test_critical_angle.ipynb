# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from fresnel import *

# %%
print("---critical angle---")
print("金刚石(24.4): {}".format(critical_angle(1/2.42**2)))
print("甘油(42.9): {}".format(critical_angle(1/1.47**2)))
print("酒精(47.3): {}".format(critical_angle(1/1.36**2)))
print("水(48.6): {}".format(critical_angle(1/1.33**2)))
# Out:
# ---critical angle---
# 金刚石(24.4): 24.407468917986588
# 甘油(42.9): 42.864910249074356
# 酒精(47.3): 47.33207450589161
# 水(48.6): 48.753466631327235
