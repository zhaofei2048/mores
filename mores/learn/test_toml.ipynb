# %%
import tomli

# %%
with open("../model.toml", "rb") as f:
    model = tomli.load(f)

# %%
model
# Out:
# {'radar': {'f': 2380000000.0},
#  'surface': {'delta': 0.0126, 'corr_len': 0.126},
#  'layer': {'thickness': 5.0,
#   'epsilon_r_background': [2.7, -0.1],
#   'epsilon_r_particle': [8.0, -0.1],
#   'axis_ratio': 1,
#   'particle_size': [0.0126, 1],
#   'particle_orientation': [0, 0]}}

# %%
model['radar']['f']
# Out:
# 2380000000.0

# %%
model['surface']['delta']
# Out:
# 0.0126

# %%
a = model['layer']['epsilon_r_background']

# %%
type(a)
# Out:
# list
