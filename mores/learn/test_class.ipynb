# %%
class Test:
    def __init__(self, name, age):
        self.name = name
        
        self.age = age
        self.print_name()
    
    def print_name(self):
        print("My name is " + self.name)
        print("And my age is " + str(self.age))

# %%
tester = Test('Tom', 26)
# Out:
# My name is Tom
# And my age is 26

# %%
a=(1,2)

# %%
(*a, *a)
# Out:
# (1, 2, 1, 2)

# %%
Test==Test
# Out:
# True
