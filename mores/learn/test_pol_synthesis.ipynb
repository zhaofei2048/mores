# %%
import numpy as np

# %%
# Mue = np.array([[11, 12, 13, 14],
#                 [21, 22, 23, 24],
#                 [311, 32, 33, 34],
#                 [41, 42, 43, 44]])
Q = np.diag([1, 1, 0.5, -0.5])
Q_BSAFSA = np.diag([1, 1, -1, -1])

# %%
# 下面测试极化合成计算和实际的sigma_qp（q为接收，p为发射）

# %%
pol_t = (0, 0)
pol_r = (0, 0)
Mue = np.random.randn(4, 4)
print('sigma_vv: {}'.format(Mue[0, 0]))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_vv: -2.4113063076924175
# -2.4113063076924175

# %%
pol_t = (0, 90)
pol_r = (0, 90)
Mue = np.random.randn(4, 4)
print('sigma_hh: {}'.format(Mue[1, 1]))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_hh: -1.037650108620816
# -1.037650108620816

# %%
pol_t = (0, 0)
pol_r = (0, 90)
Mue = np.random.randn(4, 4)
print('sigma_hv: {}'.format(Mue[1, 0]))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_hv: 0.7552251523773157
# 0.7552251523773159

# %%
pol_t = (0, 45)
pol_r = (0, 45)
Mue = np.random.randn(4, 4)
print('sigma_LL: {}'.format(0.25 * (Mue[0, 0] + Mue[1, 1] + Mue[0, 1] + Mue[1, 0] - 2 * (Mue[3, 3] - (-Mue[0, 3] + 0.5 * Mue[3, 0] + 0.5 * Mue[3, 1] - Mue[1, 3])))))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
# Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), np.sin(2*Psi_r)*np.cos(2*Chi_r), -np.sin(2*Chi_r)])
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_LL: -0.25110256260941466
# -0.2511025626094142

# %%
pol_t = (0, -45)
pol_r = (0, -45)
Mue = np.random.randn(4, 4)
print('sigma_RR: {}'.format(0.25 * (Mue[0, 0] + Mue[1, 1] + Mue[0, 1] + Mue[1, 0] - 2 * (Mue[3, 3] + (-Mue[0, 3] + 0.5 * Mue[3, 0] + 0.5 * Mue[3, 1] - Mue[1, 3])))))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
# Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), np.sin(2*Psi_r)*np.cos(2*Chi_r), -np.sin(2*Chi_r)])
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_RR: 0.5276580329792165
# 0.5276580329792167

# %%
pol_t = (0, 45)
pol_r = (0, -45)
Mue = np.random.randn(4, 4)
print('sigma_RL: {}'.format(0.25 * (Mue[0, 0] + Mue[1, 1] + Mue[0, 1] + Mue[1, 0] + 2 * (Mue[3, 3] + (-Mue[0, 3] - 0.5 * Mue[3, 0] - 0.5 * Mue[3, 1] - Mue[1, 3])))))

Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_RL: -1.2998951973305821
# -1.2998951973305821

# %%
pol_t = (0, -45)
pol_r = (0, 45)
Mue = np.random.randn(4, 4)
print('sigma_LR: {}'.format(0.25 * (Mue[0, 0] + Mue[1, 1] + Mue[0, 1] + Mue[1, 0] + 2 * (Mue[3, 3] - (-Mue[0, 3] - 0.5 * Mue[3, 0] - 0.5 * Mue[3, 1] - Mue[1, 3])))))
# print('sigma_LR: {}'.format(0.25 * (Mue[0, 0] + Mue[1, 1] + Mue[0, 1] + Mue[1, 0] + 2 * (Mue[3, 3] - (Mue[0, 3] - 0.5 * Mue[3, 0] - 0.5 * Mue[3, 1] + Mue[1, 3])))))
Psi_r, Chi_r = np.deg2rad(pol_r)
Psi_t, Chi_t = np.deg2rad(pol_t)

# normalized stokes vectors of transmitting and receiving antennas
Int = np.array([0.5*(1+np.cos(2*Psi_t)*np.cos(2*Chi_t)), 0.5*(1-np.cos(2*Psi_t)*np.cos(2*Chi_t)), np.sin(2*Psi_t)*np.cos(2*Chi_t), -np.sin(2*Chi_t)])
Inr = np.array([0.5*(1+np.cos(2*Psi_r)*np.cos(2*Chi_r)), 0.5*(1-np.cos(2*Psi_r)*np.cos(2*Chi_r)), -np.sin(2*Psi_r)*np.cos(2*Chi_r), np.sin(2*Chi_r)]) # the minus on 3-th and 4-th elements of Inr is due to the inversed propagation
sigma0 = 4 * np.pi * (np.dot(Inr, Q @ Q_BSAFSA @ Mue @ Int))
sigma0/(4*np.pi)
# Out:
# sigma_LR: -0.8903321622849715
# -0.8903321622849718
