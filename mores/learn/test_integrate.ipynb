# %%
import numpy as np
import scipy.integrate as integrate

# %%
fx = lambda x: np.array([[1, 2], [3, 4]]) @ np.array([[np.sin(x), 2*np.sin(x)], [x, x**2]]) @ np.array([[np.sin(x), 2*np.sin(x)], [x, x**2]])
integrate.quad_vec(fx, 0, 1)
# Out:
# (array([[1.97735036, 2.59651455],
#         [4.82971372, 6.18486894]]),
#  2.830978115320132e-13)

# %%
1-np.cos(1)
# Out:
# 0.45969769413186023

# %%
fx = lambda x: np.array([[x, np.cos(x)], [1, x**2]]) @ np.array([[x**2, x**3], [np.sin(x), 2]])
integrate.quad_vec(fx, 0, 1)
# Out:
# (array([[0.60403671, 1.88294197],
#         [0.55657761, 0.91666667]]),
#  7.803126523401478e-14)

# %%
integrate.quad(lambda x:x**3+np.cos(x)*np.sin(x), 0, 1)
# Out:
# (0.6040367091367855, 6.70615462202468e-15)

# %%
# !conda info
# Out:
#      active environment : gis
#     active env location : D:\app\anaconda\envs\gis
#        user config file : C:\Users\zhaofei\.condarc
#  populated config files :
#           conda version : 23.7.2
#     conda-build version : 3.26.0
#          python version : 3.11.4.final.0
#        virtual packages : __archspec=1=x86_64
#                           __win=0=0
#        base environment : D:\app\anaconda  (writable)
#       conda av data dir : D:\app\anaconda\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : D:\app\anaconda\pkgs
# ...
